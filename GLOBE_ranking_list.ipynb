# %% [markdown]
# ##Script for listing all GLOBE schools with more than 10 000 rows of data
#
# ---
#
# I made this script because I wanted to make a better list of GLOBE schools with many measurements. At first, I tried to look at official metrics (https://www.globe.gov/about/impact-and-metrics/schools-with-many-measurements). Unfortunately, the number of data there was different from the number on official schools pages.
#
# I asked for an explanation on the GLOBE forum, and I got the following response:
#
# > "Different areas of the website count measurements differently.  Some places count the number of rows of data across several database tables.  Other places count specific table cells in select tables.  Depending on the protocol there are occasions where just specific samples are counted.  The https://www.globe.gov/about/impact-and-metrics/schools-with-many-measurements advertises "Approximate number of measurements" so it is not meant to be exact counts."
#
# So, in the end, I wrote this simple script that can give you a list of all schools with >= 10 000 data rows ordered by the number of data on their main page.
#
# Important note: Citizen science national accounts are not included in this ranking.

# %%
from bs4 import BeautifulSoup
import requests
import sys

# %%
url_list = ["https://www.globe.gov/about/impact-and-metrics/schools-with-many-measurements/100000-499999",
            "https://www.globe.gov/about/impact-and-metrics/schools-with-many-measurements/50000-99999",
            "https://www.globe.gov/about/impact-and-metrics/schools-with-many-measurements/10000-49999"]

# %%
def get_list_of_globe_schools():

    list_of_globe_schools=[]

    for link in url_list:
        page = requests.get(link)    
        data = page.text
        soup = BeautifulSoup(data)

        for table in soup.find_all('table'):
            for link in table.find_all('a'):
                list_of_globe_schools.append(link.get('href'))
    
    return list_of_globe_schools

# %%
def get_number_of_data(list_of_globe_schools):
    final_data=[]
    for link in list_of_globe_schools:
      try:
            page = requests.get(link)
            name=link[26:]
            data = page.text
            soup = BeautifulSoup(data)
            statistics=soup.find_all("div", class_="participation-count-column")[1]
            number_of_observations = statistics.text.strip().split("\n")
            final_data.append((name,int(number_of_observations[0])))
      except IndexError as e:
         print (link,e)   
    
    final_data.sort(key=lambda x: x[1],reverse=True)

    return final_data

# %%
list_of_globe_schools=get_list_of_globe_schools()

# %%
final_data=get_number_of_data(list_of_globe_schools)
# Out:
# https://www.globe.gov/web/united-states-of-america-citizen-science list index out of range
# https://www.globe.gov/web/canada-citizen-science list index out of range
# https://www.globe.gov/web/india-citizen-science list index out of range
# https://www.globe.gov/web/thailand-citizen-science list index out of range

# %%
for i in final_data:
  print(i[0],i[1])
# Out:
# dsmweather 39872122
# mittelschule-elsterberg 30705310
# earth-networks-globe-v-school 20552483
# globe-one-automated-weather-stations 5375526
# university-of-cologne-glidt256- 4836481
# norfork-elementary-school 4699369
# sumarska-i-drvodjeljska-skola 4517244
# missouri-globe-v-school 2288004
# hills-home-school 2160953
# edmund-burke-school 1916759
# gimnazium-in-toszek 1672460
# southern-connecticut-state-university-usctnilj- 1613664
# university-of-toledo-school 1592436
# ramey-school 1579013
# ncar-foothills-lab 1523044
# littleton-middle-school 1451041
# palmyra-cove-nature-park-pcnp- 1400702
# virginia-museum-of-natural-history1 1349268
# o.j.roberts-middle-school 1339673
# trinity-school 1328912
# 273129 1306145
# mcknight-middle-school 1286941
# mahopac-high-school 1156424
# stone-child-college-usmtgcz3- 1155821
# north-shore-hebrew-academy-high-school 1135425
# 238824 1125782
# lourdes-public-charter-school 1113176
# united-states-of-america-globe-v-school 1042375
# 312849 1009488
# ruth-cherry-intermediate-school 998149
# northland-pines 992688
# ies-itaca 954580
# freedom-high-school-usvagzgj- 878095
# os-sime-budinica 877200
# athens-intermediate-school 866538
# skola-za-medicinske-sestre-vrapce 827993
# pompano-beach-high-school 808768
# crestwood-high-school 753424
# kutztown-area-middle-school 752548
# long-beach-senior-high-school-nike-environmental-center 741225
# loxley-elementary-school 735766
# magnolia-high-school-uswvogsv- 729995
# canyon-weather 693795
# fayetteville-high-school 653883
# st-joan-of-arc 653065
# cardinal-gibbons-high-school 627213
# conrad-weiser-middle-school-glidpyza- 620627
# morristown-beard-school 612115
# lickhill-lodge-first 605750
# memorial-middle-school-glids7mf- 589616
# gimnazjum-no-2-plplcg9b- 582362
# vang-barne-og-ungdomsskule-6-16- 562126
# norfork-passive-irrigation-experiment 547010
# globe-program-office-globe-v-school 537974
# stowe-elementary-school 500420
# norfork-rebels-4-h-club 480249
# victory-elementary-science-center 451229
# ekonomska-i-trgovacka-skola-dubrovnik 449360
# waynesboro-senior-high-school 410199
# 186686 399478
# 271369 381134
# national-kinmen-senior-high-school 381078
# florida-state-university 365444
# houjia-junior-high-school 349108
# frank-e.-weiss-elementary 336309
# 138872 332321
# innoko-river-school 324640
# nasa-goddard-space-flight-center-usmdjut3- 298068
# wanaka-field-station 287860
# kaohsiung-youchang-junior-high-school 282109
# the-first-arqah-secondary-school-al-riyadh 242412
# ies-m-aurelia-capmany 228148
# os-banija 218891
# eugenio-m.-hostos 201187
# gimnazjum-in-sulow 193218
# utajarven-ylaaste 176133
# os-antuna-mihanovica-hrhrbbit- 174526
# 3rd-lyceum-of-aigaleo 172020
# banyangsung 144148
# ies-esteban-manuel-de-villegas 142579
# 43615 130589
# hartland-consolidated-school 113505
# kingsburg-high-school 105473
# 141446 105230
# xi-liceum-st.-konarskiego 91218
# offene-schule-babenhausen 84439
# the-20th-secondary-girls-school 81036
# al-farouk 79797
# alexander-von-humboldt-gymnasium 77870
# ratsgymnasium-wolfsburg 76962
# the-24th-seconadry-girls-school-at-makkah-al-mukarramah 74653
# tabor-academy 74264
# srednja-skola-petrinja 72079
# os-matija-gubec 71782
# the-25th-secondary-girls-school 68916
# gymnasium-ohmoor 68289
# kilingi-nomme-gymnasium 67352
# 141391 66161
# os-dubovac 65036
# srednja-skola-mate-blazine-labin 63832
# srednja-skola-prelog 63534
# hamzah-bin-abdulmutalib 62520
# zakladni-skola-czczieni- 62482
# tehnicka-skola-daruvar 60722
# yamama 60467
# the19th-secondary-girls-school-at-al-madinah-al-monawarah 59761
# tyri-gymnasium 58706
# gimnazija-petra-preradovica 56616
# gimnazija-matija-mesic 56339
# stredni-prumyslova-skola-otrokovice 56004
# os-konjscina 54211
# mid-valley-secondary-center 53859
# os-antuna-mihanovica 53524
# os-mate-lovraka 52579
# os-i.g.-kovacic 51486
# akmenes-gimnazija 51098
# os-prof.-f.v.-signjara 50984
# prirodoslovna-i-graficka-skola 50809
# medicinska-skola-varazdin 50244
# the-199th-intermediate-girls-school 50035
# alsedeeq-secondary-school 49867
# 4.-zakladni-skola-ekolog.-praktikum 48571
# os-valentin-klarin 48240
# os-hugo-badalic 48007
# makkah-secondary-school 46953
# os-djuro-pilar 45179
# pasvalys-p.-vileisis-gymnasium 44699
# ii-gimnazija-zagreb 44698
# anyksciu-raj.-troskunu-k.-inciuros-vidurine-mokykla 44062
# liechtensteinisches-gymnasium 43861
# primarschule-neufeld 43800
# nawan-secondary-girls-school-at-al-makhwah 43495
# os-josip-pupacic 43381
# gymnazium-dr.-a.-hrdlicky 43010
# bocskai-istvan-gimnazium-szakkepz-iskola-es-kollegium 42240
# 143-secondery-school-at-riyadh 41952
# os-zadarski-otoci 41547
# complex-of-secondary-schools 41487
# os-ksavera-sandora-djalskog 41401
# palokan-ylakoulu 40335
# ies-eusebio-barreto 40042
# muhu-comprehensive-school 39866
# liceo-scientifico-n.-da-recco-sede-stacc.-rapallo 39249
# zenska-opca-gimnazija-druzbe-sestara-milosrdnica-s-pravom-javn. 39152
# dietrich-bonhoeffer-schule-staatliche-regelschule- 38672
# os-draganici 38506
# os-bedekovcina 38332
# ekonomsko-birotehnicka-i-trgovacka-skola 38190
# 20826740 37793
# l2r 37486
# zakladni-skola-josefa-bublika-banov 37360
# konigliches-athenaum-eupen 36772
# iii.-osnovna-skola-varazdin 36678
# os-belica 36184
# gymnazium 36053
# gimnazija-karlovac 35886
# elementary-school-no-10-j.-korczaka 35859
# os-vladimira-nazora 35785
# tallinn-secondary-science-school 35726
# ivano-frankivsk-city-environmental-station 35699
# os-petar-zrinski 35528
# ii.-osnovna-skola-cakovec 34892
# rongu-secondary-school 34861
# palangos-baltijos-vidurine-mokykla 34373
# bundeshandelsakademie-und-bundeshandelsschule-bregenz 34280
# os-mahicno 34225
# zakladni-skola-opavska 34181
# al-matan-intermediate-and-secondary-girls-school-at-sabya 33969
# reynolds-jr-sr-high-school 33750
# staatliche-realschule 33691
# brazil-globe-v-school 33625
# primary-school-no-1-in-gora 33237
# zakladni-skola-czczaxwv- 32827
# zs-trebic 32814
# facultad-de-estudios-superiores-cuautitlan 32356
# zs-vrane-nad-vltavou 32141
# complex-of-schools-in-rudna-wielka 32015
# vannarodsskolan 31931
# srednja-skola-vela-luka 31817
# os-ivana-kukuljevica 31571
# most-pure-heart-of-mary 31414
# complex-of-schools-kard.-st.wyszynskiego-in-jadachy 31164
# al-hayathem-intermediate 30642
# ies-margarita-de-fuenmayor 30221
# os-ljubo-babic 30205
# goethe-schule 30035
# gimnazjum-no-9-sw.-krolowej-jadwigi 29883
# zemynos-pro-gimnazium 29760
# public-hikijidai-junior-high-school 29606
# os-dragutin-tadijanovic 29563
# escuela-primaria-particular-incorporada-n.-1345 29384
# ies-a-pinguela 29380
# charleston-elementary-school 29256
# wilhelm-erb-gymnasium 28874
# os-eugena-kumicica 28803
# ies-o-ribeiro 28754
# os-cetingrad 28430
# complex-of-schools-no-2-in-koszalin 28331
# lowrey-elementary-school 28158
# walailak-university 27906
# brazil-high 27660
# volksschule-petersaurach 27630
# ies-juan-carlos-i 27541
# c.r.-jakobsoni-gymnasium 27280
# complex-of-schools-comprehensive-school-technical-school 27197
# primarschule-trittenbach 27082
# the-9th-secondary-girls-school 27053
# os-rikard-katalinic-jeretov 26948
# staedtisches-gymnasium-grotenbach 26823
# al-habeel-secondary-school-for-girls-at-al-gunfodah 26759
# al-masaudi 26642
# xv.-gimnazija 26573
# abd-elmajeed-bin-abd-alaziz-high-school 26102
# gordan-college 25996
# rogne-skole 25693
# abdulah-bin-salam-secandary-school-at-al-ahsa 25578
# elementary-school 25496
# foerderzentrum-erding 25200
# university-of-texas-at-el-paso 25054
# rakke-gymnasium 25029
# taaksi-basic-school 24922
# complex-of-schools-in-jaroslaw 24671
# os-nedelisce 24530
# wu-ling-senior-high-school 24325
# europagymnasium-walther-rathenau-bitterfeld 24011
# gimnazium-in-waliszew 23901
# complex-of-schools-no-1 23803
# palupera-primary-school 23436
# kossuth-lajos-gimnazium 23433
# al-fatih 23044
# at-tahawy-high-school 22987
# zakladni-skola-czczkvtd- 22909
# king-saud-complex 22741
# the-1st-secondary-girls-school-at-dhahran 22426
# gimnazium-no-10-tadeusza-kosciuszki 22149
# is-hermannsburg 22114
# gymnasium-baeumlihof 21997
# ceg1-lokossa 21955
# the-1st-al-mthulif-secondary-girls-school-at-al-gonfutha 21849
# os-ljudevita-gaja 21744
# berufskolleg-institut-dr.-flad 21687
# 91256 21627
# sillamae-kannuka-gymnasium 21589
# 141413 21427
# istituto-tecnico-industriale-ferraris 21241
# instituto-isaac-peral 21097
# os-kraljice-jelene 21077
# myllyharjun-lukio 20973
# os-murterski-skoji 20876
# haripur-primary-school 20616
# ies-alonso-berruguete 20588
# srednja-skola-braca-radic 20580
# kaohsiung-municipal-cianjin-junior-high-school 20566
# rossmoor-elementary-school 20447
# escuela-rural-de-niebla 20428
# al-ahsa-secondary-school 20376
# hawazin-secondary-school 20252
# silesian-technical-scientific-schools 20107
# 240086 20051
# opunake-high-school-nznzcjs3- 19819
# elementary-school-no-88-in-poznan 19812
# croatia-globe-v-school 19783
# gimnazjum-no-7-jana-iii-sobieskiego 19738
# university-of-texas-at-tyler-campus 19732
# ies-zorrilla 19698
# v.-gimnazija-vladimir-nazor- 19621
# prince-sultan 19504
# sigdal-ungdomsskole-13-16- 19400
# os-nikole-tesla 19371
# paide-gymnasium 19370
# gimnazium-in-pakoslaw 19292
# jordet-skole 19243
# crescent-elk-school 19229
# os-marije-juric-zagorke 18914
# shahda-med 18818
# gymnasium-grossenhain 18702
# gbhs-ndop 18659
# escuela-de-ensenanza-media-7-nicolas-copernico- 18584
# the-2nd-secondary-girls-school-at-al-mobraz 18565
# ies-escultor-daniel 18343
# zakladni-skola-rokytnice 18340
# suure-jaani-gymnasium 18303
# gold-trail-school 18293
# elementary-school-no-247 18180
# franz-marc-gymnasium 18130
# sou-goce-delchev- 18129
# ies-bergidum-flavium 18019
# kaapa-comprehensive-school 17939
# enon-kirkonkylan-ala-aste 17926
# complex-of-schools-c.k.-norwida 17914
# pasvalio-levens-pagrindine-mokykla 17913
# ceg1-natitingou 17884
# al-khalig-school 17835
# os-marija-bistrica 17795
# revadevi-sovaniya-sikhashram 17079
# os-sokolovac 16911
# al-hussein-bin-ali-secondary-school 16848
# west-elementary-school-usohmn3r- 16822
# os-tisno 16814
# secondary-school-of-laranjeiras 16779
# os-vladimira-nazora-hrhryu6g- 16700
# os-matija-antun-relkovic 16635
# mississippi-height-middle-school 16348
# abu-bakr-as-siddiq-intermediate-school 16343
# national-chang-hua-senior-high-school 16311
# vestvaagoey-videregaaende-skole 16307
# peace-schools-network 16297
# os-privlaka 16184
# hedwig-bollhagen-gymnasium-velten 16137
# hahira-middle-school 16027
# alkameesh-5intermedia-school-at-alhessa 15959
# prirodoslovna-tehnicka-skola-split 15850
# ferson-creek-elementary-school 15789
# lycee-behanzin 15739
# hotelijersko-turisticka-i-ugostiteljska-skola 15711
# os-maria-martinolica 15679
# integrovana-stredni-skola 15670
# moreau-elementary-school 15598
# the-45th-secondary-girls-school-at-makkah-al-mukarramah 15549
# hays-high-school 15460
# princess-chulabhorn-s-college 15395
# ies-juana-de-pimentel 15262
# gymnazium-dacice 15243
# margaret-g.-barksdale-elementary-school 15194
# sps-karvina 15175
# kizu-town-recycring-education-station 15145
# complex-of-schools-no-48 15065
# os-vocin 15064
# lycee-mamadou-m-bodj-de-sebenikuo-lmbs- 15002
# 73568 15001
# vilniaus-fabijoniskiu-vidurine-mokykla 14944
# many-farms-high-school 14895
# the-97th-secondary-girls-school-at-jeddah 14806
# istituto-tecnico-industriale-belluzzi 14784
# king-fahad 14774
# srednja-skola-delnice 14685
# os-dragojle-jarnevic 14627
# hiteen 14599
# saukville-elementary-school 14576
# os-ivana-filipovica-osijek 14543
# gymnazium-czczma4w- 14474
# lycee-seydina-limamoulaye 14452
# okemos-high-school 14452
# voore-comprehensive-school 14436
# 73183 14421
# ripton-elementary-school 14352
# ecopolis-center-junior-eco-club 14255
# ies-cardenal-pardo-tavera 14145
# john-middleton-school-elementary-school 14083
# suanmon-school 14050
# max-planck-schule 13973
# holmes-middle-school 13945
# hollolan-ylaaste 13940
# ferdinand-steinbeis-realschule 13934
# state-university-of-new-york-at-fredonia1 13894
# kohler-public-schools 13802
# 120381 13798
# 73579 13718
# gymnasium-nova-paka 13695
# svc-domecek 13656
# the-5th-secondary-girls-school-at-taif 13653
# faifa-intermediate-and-secondary-school-at-sabya 13648
# complex-of-engineering-and-environmental-protection-schools 13622
# tenno-minami-junior-high-school 13548
# 105655 13430
# o.s.-jurja-habdelica 13139
# emerson-school-usmem7qq- 12895
# zakladni-skola-mohelnice 12847
# tartu-kivlinna-gymnasium 12833
# ies-lorenzo-hervas-y-panduro 12832
# sarala-high-school 12800
# rakvere-science-high-school 12744
# ceg-adjohoun 12738
# gimnazium-por.-j.czumy 12651
# xxvi-liceum-k.-k.-baczynskiego 12611
# gunma-prefectural-institute-of-pubric-health-and-enviornmental 12422
# escuela-provincial-no.-38-julio-a-roca-a-globe-school-in-esperanza-antarctica 12410
# kinnarin-koulu 12349
# 73667 12290
# ies-vela-zanetti 12277
# zakladni-skola-dubnany-prispevkova-organizace 12232
# 12996427 12151
# ies-gredos 12144
# ies-los-albares 12110
# miyagi-junior-high-school 12063
# govt.-girls-high-school-glide8ns- 12026
# lycee-jean-laborde 11976
# iii-liceum-a.-mickiewicza-and-gimnazjum-no.-47 11892
# stredni-lesnicka-skola 11863
# dr-ibrahim-temo-niko-nestor 11822
# os-josipa-kozarca 11502
# the-school-of-nature-environment 11272
# salman-al-farisy 11259
# the-128-intermediate-gifted-girls-school-at-jeddah 11053
# scistarter-science-for-citizens-llc-globe-v-school 10326
# complex-of-schools-gen.-d.-chlapowskiego 10248
# worthen-c-of-e-primary-school 9721
# gimnazjum-no1 9592
# jugendtechnikschuleberlin 9551
# mat-su-career-and-technical-high-school 8582
# young-naturalists-station-of-velyka-pusarivka-sumy-region 8385
# purkynovo-gymnazium-straznice 8258
# panevezio-gamtos-mokykla 7215
